# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
# Read the dataset from CSV
data = pd.read_csv('players_20.csv')
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
# get the number of missing data points per column
missing_values_count = data.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count[0:10]
# Out:
# sofifa_id      0
# player_url     0
# short_name     0
# long_name      0
# age            0
# dob            0
# height_cm      0
# weight_kg      0
# nationality    0
# club           0
# dtype: int64

# %%
# look at the # of missing points in the first ten columns
missing_values_count[0:40]
# Out:
# sofifa_id                       0
# player_url                      0
# short_name                      0
# long_name                       0
# age                             0
# dob                             0
# height_cm                       0
# weight_kg                       0
# nationality                     0
# club                            0
# overall                         0
# potential                       0
# value_eur                       0
# wage_eur                        0
# player_positions                0
# preferred_foot                  0
# international_reputation        0
# weak_foot                       0
# skill_moves                     0
# work_rate                       0
# body_type                       0
# real_face                       0
# release_clause_eur           1298
# player_tags                 16779
# team_position                 240
# team_jersey_number            240
# loaned_from                 17230
# ...

# %%
# remove all the rows that contain a missing value
data.dropna()
# Out:
# Empty DataFrame
# ...

# %%
print(data.isnull().sum())
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            2036
# lcb           2036
# cb            2036
# rcb           2036
# rb            2036
# Length: 104, dtype: int64

# %%
# Replace NaN values with 0
data = data.fillna(0)

# %%
# Save the modified data to a new CSV file
data.to_csv('player_modified.csv', index=False)

# %%
# Load the scaled data from data_scaled.csv into a pandas DataFrame
data_scaled = pd.read_csv('data_scaled.csv')
X = data_scaled[['goalkeeping_kicking', 'attacking_finishing', 'defending_marking']]
dbscan = DBSCAN(eps=0.2, min_samples=5).fit(X)  # Adjust the parameters according to your data
DBSCAN_dataset = X.copy()

DBSCAN_dataset.loc[:,'Cluster'] = clustering.labels_

# %%
# Load the scaled data from data_scaled.csv into a pandas DataFrame
#data_scaled = pd.read_csv('data_scaled.csv')

# Select the input features (X) for clustering
#X = data_scaled[['goalkeeping_kicking', 'attacking_finishing', 'defending_marking']]

# Apply DBSCAN
#dbscan = DBSCAN(eps=0.2, min_samples=5)  # Adjust the parameters according to your data
#dbscan.fit(X)



DBSCAN_dataset.loc[:,'Cluster'] = clustering.labels_ 
DBSCAN_dataset.Cluster.value_counts().to_frame()
# Add the cluster labels to the DataFrame
data_scaled['Cluster'] = labels

# Get the outliers
outliers = data_scaled[data_scaled['Cluster'] == -1]

# Create the 3D scatter plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot the clustered data points
ax.scatter(data_scaled['goalkeeping_kicking'][labels != -1], data_scaled['attacking_finishing'][labels != -1], data_scaled['defending_marking'][labels != -1], c=labels[labels != -1], cmap='Set2', s=60)

# Plot the outliers
ax.scatter(outliers['goalkeeping_kicking'], outliers['attacking_finishing'], outliers['defending_marking'], c='black', marker='o', label='Outliers')

# Set labels and title
ax.set_xlabel('Goalkeeping Kicking')
ax.set_ylabel('Attacking Finishing')
ax.set_zlabel('Defending Marking')
ax.set_title('DBSCAN Clustering')

# Add legend
ax.legend()
# Print the number of clusters
num_clusters = len(set(labels)) - (1 if -1 in labels else 0)
print(f"Number of clusters: {num_clusters}")

# Print the number of outliers/noise points
num_outliers = len(outliers)
print(f"Number of outliers/noise points: {num_outliers}")

# Show the plot
plt.show()
# Out:
# Number of clusters: 4
# Number of outliers/noise points: 115
